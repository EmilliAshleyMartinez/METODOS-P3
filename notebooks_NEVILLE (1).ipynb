# %%
from math import *
import numpy as np
import matplotlib . pyplot as plt
#MARTINEZ PEREA EMILLI

# %%
#def puntox(x):
x=np.array([1 ,1.3 ,1.6 ,1.9 ,2.2])
    #return x

#def puntoy(x):
y=np.array([0.7651977 ,0.6200860 ,0.4554022 ,0.2818186 ,0.1103623])
    #return f(xi)

n=x.size
#def q(x):
Q=np.zeros((n,n))
    
xi= 1.5
yi =0
k=0

# %%
print("# i\t xi \t f(xi) \t\t Qi,1 \t\t Qi,2 \t\t Qi,3 \t\t Qi,4")
#print("{0}\t{1:6.4f} \t {2:6.4f} \t {3:6.4f} \t {4:6.4f} \t {5:6.4f} \t {6:6.4f}".format(k,x[0], y[0] , G[0,0], G[1,0], G[2,0], G[3,0]))

# Calcula las interpolaciones y compara sus valores
Q [: ,0]= y
for w in range(n):
    for i in range (1,n ) :
        for j in range (1,i +1) :
            Q [i , j ]=(( xi - x [i - j ]) * Q [i ,j -1] -( xi - x [ i ]) * Q [i -1 ,j -1]) /( x [ i ] - x[i - j ])
            yi = Q [i , i ]
            k+=1
            if abs( Q [i , i ] - Q [i -1 ,i -1]) <(1*e) -5:
                exit
    print("{0}\t{1:6.4f} \t {2:6.4f} \t {3:6.4f} \t {4:6.4f} \t {5:6.4f} \t {6:6.4f}".format(w,x[w], y[w] , Q[w,1], Q[w,2], Q[w,3], Q[w,j]))
  

print("El valor aproximado de",xi," es:" ,yi,) 
#print("{0} \t\t {1:6.6f} \t {2:6.6f} \t {3:6.6f} \t {4:6.6f}".format(niter, a, fp, error, error ))
            
plt.plot (x ,y ,'o')
plt.plot ( xi , yi ,'o')
plt.text ( xi +0.1 , yi , str( yi ) )
plt.title ('Metodo Neville')
plt.legend ([ 'Puntos dados ',' Interpolación '])
plt.grid ( True )
plt.show ()
# Out:
# # i	 xi 	 f(xi) 		 Qi,1 		 Qi,2 		 Qi,3 		 Qi,4
# 0	1.0000 	 0.7652 	 0.0000 	 0.0000 	 0.0000 	 0.0000
# 1	1.3000 	 0.6201 	 0.5233 	 0.0000 	 0.0000 	 0.0000
# 2	1.6000 	 0.4554 	 0.5103 	 0.5125 	 0.0000 	 0.0000
# 3	1.9000 	 0.2818 	 0.5133 	 0.5113 	 0.5118 	 0.0000
# 4	2.2000 	 0.1104 	 0.5104 	 0.5137 	 0.5118 	 0.5118
# El valor aproximado de 1.5  es: 0.5118199942386831
